# %% [markdown]
# # DELIVERABLE 1: Retrieve Weather Data

# %%
#3.Create a new set of 2,000 random latitudes and longitudes
import pandas as pd
import numpy as np
import random

lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs) #pack
coordinates = list(lat_lngs) #unpack

# %%
#4.Get the nearest city using the citipy module.
from citipy import citipy

cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
cities
# Out:
# ['ushuaia',
#  'harper',
#  'saint anthony',
#  'port alfred',
#  'pastavy',
#  'talnakh',
#  'hermanus',
#  'cape town',
#  'margate',
#  'muzhi',
#  'winchester',
#  'vardo',
#  'muisne',
#  'sao sebastiao',
#  'ponta do sol',
#  'barentsburg',
#  'tasiilaq',
#  'leshukonskoye',
#  'khor',
#  'hithadhoo',
#  'nanortalik',
#  'busselton',
#  'ouesso',
#  'taolanaro',
#  'belushya guba',
#  'eganville',
#  'mar del plata',
#  'amderma',
#  'illoqqortoormiut',
#  'manadhoo',
#  'mahebourg',
#  'nouadhibou',
#  'barauna',
#  'port elizabeth',
#  'camacha',
#  'punta arenas',
#  'saint-philippe',
#  'walvis bay',
#  'kensington',
#  'belmonte',
#  'victoria',
#  'henties bay',
#  'vila velha',
#  'geraldton',
#  'marovoay',
#  'caravelas',
#  'borodino',
#  'upernavik',
#  'arraial do cabo',
#  'strai',
#  'bredasdorp',
#  'garowe',
#  'trairi',
#  'mumford',
#  'ostrovnoy',
#  'juliaca',
#  'saint george',
#  'tonantins',
#  'sezana',
#  'qaanaaq',
#  'turayf',
#  'pondicherry',
#  'east london',
#  'mangrol',
#  'dikson',
#  'togur',
#  'umm lajj',
#  'crossville',
#  'tallahassee',
#  'roald',
#  'saint-augustin',
#  'san cristobal',
#  'kharan',
#  'yining',
#  'bumba',
#  'torbay',
#  'vestmannaeyjar',
#  'goya',
#  'mold',
#  'panguipulli',
#  'maragogi',
#  'iqaluit',
#  'qasigiannguit',
#  'santa barbara',
#  'ambilobe',
#  'saldanha',
#  'campos novos',
#  'gornopravdinsk',
#  'pedernales',
#  'pangnirtung',
#  'mutare',
#  'methoni',
#  'huite',
#  'olafsvik',
#  'lovrenc na pohorju',
#  'cayenne',
#  'aflu',
#  'jamestown',
#  'souillac',
#  'luderitz',
#  'azrow',
#  'yurino',
#  'isparta',
#  'tumannyy',
#  'adrar',
#  'faranah',
#  'ancud',
#  'de aar',
#  'warqla',
#  'erba',
#  'kaabong',
#  'havre-saint-pierre',
#  'grindavik',
#  'kuytun',
#  'eenhana',
#  'taklisah',
#  'ilulissat',
#  'klaebu',
#  'ribeira grande',
#  'melo',
#  'taltal',
#  'joao pinheiro',
#  'augusto correa',
#  'pereira barreto',
#  'georgetown',
#  'varberg',
#  'chuy',
#  'oktyabrskoye',
#  'manaquiri',
#  'manta',
#  'sinazongwe',
#  'noyabrsk',
#  'pisco',
#  'comodoro rivadavia',
#  'bengkulu',
#  'bud',
#  'bargal',
#  'hit',
#  'lagoa',
#  'mahadday weyne',
#  'saint-leu',
#  'longyearbyen',
#  'quatre cocos',
#  'sakakah',
#  'porbandar',
#  'muros',
#  'klaksvik',
#  'amparafaravola',
#  'bubaque',
#  'rocha',
#  'morondava',
#  'sinnamary',
#  'sao joao da barra',
#  'oktyabrskiy',
#  'bartica',
#  'troitskoye',
#  'mao',
#  'raudeberg',
#  'sidrolandia',
#  'mormugao',
#  'oxelosund',
#  'yarada',
#  'bambous virieux',
#  'shelburne',
#  'varna',
#  'selma',
#  'rio grande',
#  'port hawkesbury',
#  'hammerfest',
#  'abiy adi',
#  'maniitsoq',
#  'verkhnyaya inta',
#  'kudahuvadhoo',
#  'esperanza',
#  'lebu',
#  'makat',
#  'paracuru',
#  'peniche',
#  'male',
#  'cidreira',
#  'cabedelo',
#  'namibe',
#  'wronki',
#  'salinopolis',
#  'plattsburgh',
#  'skjervoy',
#  'safranbolu',
#  'korla',
#  'hearst',
#  'navlya',
#  'ndele',
#  'alfreton',
#  'thinadhoo',
#  'lidkoping',
#  'kamenka',
#  'hofn',
#  'isla mujeres',
#  'azare',
#  'zdvinsk',
#  'leh',
#  'constitucion',
#  'liwale',
#  'kalabo',
#  'grand river south east',
#  'gat',
#  'rio cuarto',
#  'castro',
#  'kalmunai',
#  'mizan teferi',
#  'synya',
#  'bathsheba',
#  'codrington',
#  'attawapiskat',
#  'gamba',
#  'ginir',
#  'dwarka',
#  'masvingo',
#  'vallenar',
#  'murgab',
#  'manama',
#  'kasongo-lunda',
#  'coquimbo',
#  'virginia beach',
#  'boa vista',
#  'salalah',
#  'rabo de peixe',
#  'chatakonda',
#  'kendrapara',
#  'port blair',
#  'laguna',
#  'jibuti',
#  'odesskoye',
#  'madinat sittah uktubar',
#  'louisbourg',
#  'yenagoa',
#  'cajamarca',
#  'mecca',
#  'lumeje',
#  'umm kaddadah',
#  'abnub',
#  'porto novo',
#  'itarema',
#  'ghosi',
#  'mana',
#  'jacareacanga',
#  'tsienyane',
#  'khromtau',
#  'ponta delgada',
#  'inhambane',
#  'jutai',
#  'tsihombe',
#  'bayaguana',
#  'naraina',
#  'bondo',
#  'svetlyy',
#  'mount pleasant',
#  'alakurtti',
#  'aksarka',
#  'paoua',
#  'hun',
#  'amboasary',
#  'iralaya',
#  'isakly',
#  'muana',
#  'cockburn town',
#  'palmas de monte alto',
#  'corum',
#  'daneti',
#  'artigas',
#  'priyutnoye',
#  'sechura',
#  'porto walter',
#  'diffa',
#  'qaqortoq',
#  'nekhayevskiy',
#  'kant',
#  'babanusah',
#  'ayagoz',
#  'lagos',
#  'tazovskiy',
#  'santa comba',
#  'camana',
#  'den helder',
#  'krasnoselkup',
#  'sovetskiy',
#  'maldonado',
#  'tostamaa',
#  'bandarbeyla',
#  'buta',
#  'pitimbu',
#  'narsaq',
#  'trinidad',
#  'binga',
#  'lubao',
#  'goderich',
#  'paucartambo',
#  'skala fourkas',
#  'atar',
#  'magaria',
#  'iquique',
#  'sao felix do xingu',
#  'vawkavysk',
#  'awbari',
#  'nisia floresta',
#  'mayumba',
#  'chiredzi',
#  'havoysund',
#  'los llanos de aridane',
#  'sao geraldo do araguaia',
#  'marcona',
#  'qorveh',
#  'zastron',
#  'artyshta',
#  'paamiut',
#  'sturgeon falls',
#  'tocopilla',
#  'somerset east',
#  'terrak',
#  'brae',
#  'srivardhan',
#  'alibag',
#  'karaul',
#  'sabha',
#  'bolungarvik',
#  'vila franca do campo',
#  'amalfi',
#  'caraballeda',
#  'willowmore',
#  'melbu',
#  'urucara',
#  'beira',
#  'malpe',
#  'grand gaube',
#  'anloga',
#  'ekibastuz',
#  'pizarro',
#  'marzuq',
#  'isoka',
#  'sept-iles',
#  'cartagena del chaira',
#  'bucak',
#  'mezhdurechenskiy',
#  'general pico',
#  'kiruna',
#  'monrovia',
#  'bom jesus',
#  'mugumu',
#  'saint-georges',
#  'ilinogorsk',
#  'san carlos de bariloche',
#  'araouane',
#  'kapoeta',
#  'burica',
#  'saint-pierre',
#  'nicoya',
#  'dhidhdhoo',
#  'winneba',
#  'batticaloa',
#  'jalu',
#  'sao filipe',
#  'bell ville',
#  'benghazi',
#  'chapais',
#  'nuuk',
#  'moyobamba',
#  'dothan',
#  'dharchula',
#  'taoudenni',
#  'bristol',
#  'marawi',
#  'kathmandu',
#  'jaque',
#  'edd',
#  'garissa',
#  'dourados',
#  'arona',
#  'jaisalmer',
#  'saint-paul',
#  'zaysan',
#  'mvuma',
#  'abha',
#  'pietarsaari',
#  'marsabit',
#  'visnes',
#  'dingle',
#  'carnarvon',
#  'bonfim',
#  'nouakchott',
#  'riyadh',
#  'narayangarh',
#  'zhanaozen',
#  'hamilton',
#  'monroe',
#  'yei',
#  'paita',
#  'khudumelapye',
#  'biala podlaska',
#  'liverpool',
#  'montepuez',
#  'undory',
#  'richards bay',
#  'marfino',
#  'igarka',
#  'channel-port aux basques',
#  'diego de almagro',
#  'husavik',
#  'villazon',
#  'saint-joseph',
#  'felidhoo',
#  'karkaralinsk',
#  'cozumel',
#  'inirida',
#  'las palmas',
#  'bouca',
#  'abu kamal',
#  'balkhash',
#  'kabelvag',
#  'binghamton',
#  'french harbor',
#  'ilebo',
#  'buraydah',
#  'touros',
#  'vuktyl',
#  'yegorlykskaya',
#  'brockville',
#  'progreso',
#  'pavilosta',
#  'burgos',
#  'mercedes',
#  'mjolby',
#  'samsun',
#  'mamallapuram',
#  'ipixuna',
#  'omboue',
#  'balkanabat',
#  'valdivia',
#  'ormara',
#  'viransehir',
#  'kaliganj',
#  'moose factory',
#  'camden',
#  'troyes',
#  'blacksburg',
#  'kazerun',
#  'hualmay',
#  'luanda',
#  'pidhorodne',
#  'mugla',
#  'goryachegorsk',
#  'parana',
#  'koulikoro',
#  'port-gentil',
#  'amapa',
#  'berlevag',
#  'zachagansk',
#  'cataguases',
#  'massaguet',
#  'beyneu',
#  'miguelopolis',
#  'maracas',
#  'pervomayskoye',
#  'lemesos',
#  'shache',
#  'zverinogolovskoye',
#  'nokaneng',
#  'awjilah',
#  'of',
#  'lusaka',
#  'tres arroyos',
#  'takoradi',
#  'porto murtinho',
#  'estrela',
#  'clyde river',
#  'wattegama',
#  'sur',
#  'chukhloma',
#  'sinjar',
#  'longlac',
#  'oussouye',
#  'jorpeland',
#  'merrill',
#  'turbat',
#  'worthing',
#  'berbera',
#  'solovetskiy',
#  'bom jesus da lapa',
#  'adre',
#  'kotri',
#  'kaoma',
#  'arica',
#  'malartic',
#  'gamboula',
#  'bull savanna',
#  'kruisfontein',
#  'lyngseidet',
#  'jacqueville',
#  'san pedro',
#  'kassala',
#  'mehrabpur',
#  'nizwa',
#  'paveh',
#  'cap malheureux',
#  'santa eulalia del rio',
#  'zvishavane',
#  'gayeri',
#  'barmer',
#  'bodden town',
#  'kavaratti',
#  'noicattaro',
#  'kulhudhuffushi',
#  'puri',
#  'raga',
#  'kamyshlov',
#  'loiza',
#  'svetlogorsk',
#  'west bay',
#  'bojnurd',
#  'umm jarr',
#  'george town',
#  'lar gerd',
#  'coihaique',
#  'wilmington',
#  'turtas',
#  'neuquen',
#  'mahenge',
#  'rio gallegos',
#  'wajir',
#  'viedma',
#  'bushehr',
#  'bonavista',
#  'gacko',
#  'tall kayf',
#  'arlit',
#  'rawson',
#  'jalingo',
#  'sao jose da coroa grande',
#  'dudinka',
#  'road town',
#  'sorland',
#  'sistranda',
#  'ilhabela',
#  'johi',
#  'port-cartier',
#  'mehamn',
#  'careiro da varzea',
#  'presidencia roque saenz pena',
#  'tucuma',
#  'alta floresta',
#  'emba',
#  'havelock',
#  'rosa zarate',
#  'opuwo',
#  'barabinsk',
#  'iquitos',
#  'qurayyat',
#  'umzimvubu',
#  'fabriano',
#  'bilma',
#  'bethalto',
#  'aripuana',
#  'kalmar',
#  'san nicolas',
#  'ciudad bolivar',
#  'koster',
#  'xuddur',
#  'lakki marwat',
#  'sumbawanga',
#  'dombarovskiy',
#  'el faiyum',
#  'stornoway',
#  'bad goisern',
#  'rockingham',
#  'gao',
#  'san matias',
#  'villa rica',
#  'novocheremshansk',
#  'bonthe',
#  'novoselytsya',
#  'santa lucia',
#  'doha',
#  'galbshtadt',
#  'odoyev',
#  'oranjemund',
#  'ourossogui',
#  'rio tinto',
#  'pozo colorado',
#  'imbituba',
#  'ureki',
#  'santa fe',
#  'plouzane',
#  'jiroft',
#  'kozhevnikovo',
#  'borgarnes',
#  'felipe carrillo puerto',
#  'kaimur',
#  'brigantine',
#  'bouna',
#  'palencia',
#  'vary',
#  'sambava',
#  'douglas',
#  'dolores',
#  'uusikaupunki',
#  'borba',
#  'quchan',
#  'purranque',
#  'sao raimundo nonato',
#  'bhuban',
#  'areosa',
#  'hambantota',
#  'bougouni',
#  'chimbote',
#  'bayburt',
#  'banyo',
#  'derzhavinsk',
#  'dabeiba',
#  'cochrane',
#  'tshikapa',
#  'sarh',
#  'bakel',
#  'jabinyanah',
#  'nioro',
#  'kharp',
#  'campo formoso',
#  'baneh',
#  'turinskaya sloboda',
#  'graaff-reinet',
#  'conakry',
#  'gravdal',
#  'plettenberg bay',
#  'lamu',
#  'tasbuget',
#  'zharkent',
#  'cascais',
#  'bolshoye polpino',
#  'zhanatas',
#  'jenbach',
#  'oranjestad',
#  'hurghada',
#  'lerwick',
#  'bana',
#  'wadi maliz',
#  'kargasok',
#  'mapiripan',
#  'bani',
#  'hjelset',
#  'macapa',
#  'loandjili',
#  'upata',
#  'vestmanna',
#  'canandaigua',
#  'bindura',
#  'gerash',
#  'the valley',
#  'sakaraha',
#  'baherden',
#  'winthrop',
#  'grand-lahou',
#  'komsomolets',
#  'tsumeb',
#  'itaituba',
#  'pimentel',
#  'kibaya',
#  'vilhena',
#  'ritchie',
#  'aquidaba',
#  'mahajanga',
#  'banamba',
#  'pauini',
#  'yangambi',
#  'luena',
#  'kharitonovo',
#  'ust-tsilma',
#  'tacoronte',
#  'beloha',
#  'farafangana',
#  'trincomalee',
#  'nainpur',
#  'kargil',
#  'mazamari',
#  'high rock',
#  'kuito',
#  'orichi',
#  'bandundu',
#  'faya',
#  'sabzevar',
#  'lucknow',
#  'cockburn harbour',
#  'prieska',
#  'tamandare',
#  'marsh harbour',
#  'maamba',
#  'suleja',
#  'lodja',
#  'divnoye',
#  'santa cruz',
#  'nadym',
#  'dalsingh sarai',
#  'tarnogskiy gorodok',
#  'osorno',
#  'olean',
#  'lerik',
#  'rundu',
#  'imeni tsyurupy',
#  'tyup',
#  'kosonsoy',
#  'kjollefjord',
#  'damietta',
#  'indapur',
#  'ostend',
#  'thiruvananthapuram',
#  'nioki',
#  'atasu',
#  'kangaatsiaq',
#  'kez',
#  'lasa',
#  'canto do buriti',
#  'peebles',
#  'matay',
#  'cerrito',
#  'jagatsinghapur',
#  'lodeynoye pole',
#  'matadi',
#  'chicama',
#  'fuerte olimpo',
#  'mandi',
#  'minab',
#  'qandala',
#  'buguruslan',
#  'aksay',
#  'puerto baquerizo moreno',
#  'sioux lookout',
#  'nadvoitsy',
#  'aracruz',
#  'kostomuksha',
#  'chake chake',
#  'gilgit',
#  'gazli',
#  'bela',
#  'olinda',
#  'planaltina',
#  'amalapuram',
#  'bosaso',
#  'khorramabad',
#  'bur gabo',
#  'virarajendrapet',
#  'guayaramerin',
#  'takaungu',
#  'gidam',
#  'marechal candido rondon']

# %%
#5. Perform an API call with the OpenWeatherMap.
import requests
from configg import weather_api_key


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8c6393ad49bd04df6097290b56bb7149

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count. 
    record_count += 1

# Run an API request for each of the cities.
    try: 
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data_list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity, 
                          "Cloudiness": city_clouds, 
                          "Wind Speed": city_wind, 
                          "Country": city_country, 
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate the Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | harper
# Processing Record 3 of Set 1 | saint anthony
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | pastavy
# Processing Record 6 of Set 1 | talnakh
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | margate
# Processing Record 10 of Set 1 | muzhi
# Processing Record 11 of Set 1 | winchester
# Processing Record 12 of Set 1 | vardo
# Processing Record 13 of Set 1 | muisne
# Processing Record 14 of Set 1 | sao sebastiao
# Processing Record 15 of Set 1 | ponta do sol
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | tasiilaq
# Processing Record 18 of Set 1 | leshukonskoye
# Processing Record 19 of Set 1 | khor
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | nanortalik
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | ouesso
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | eganville
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | manadhoo
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | nouadhibou
# Processing Record 33 of Set 1 | barauna
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | camacha
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | walvis bay
# Processing Record 39 of Set 1 | kensington
# Processing Record 40 of Set 1 | belmonte
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | henties bay
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | marovoay
# Processing Record 46 of Set 1 | caravelas
# Processing Record 47 of Set 1 | borodino
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | strai
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | garowe
# Processing Record 3 of Set 2 | trairi
# Processing Record 4 of Set 2 | mumford
# Processing Record 5 of Set 2 | ostrovnoy
# Processing Record 6 of Set 2 | juliaca
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | tonantins
# Processing Record 9 of Set 2 | sezana
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | turayf
# Processing Record 12 of Set 2 | pondicherry
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | mangrol
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | togur
# Processing Record 17 of Set 2 | umm lajj
# Processing Record 18 of Set 2 | crossville
# Processing Record 19 of Set 2 | tallahassee
# Processing Record 20 of Set 2 | roald
# Processing Record 21 of Set 2 | saint-augustin
# Processing Record 22 of Set 2 | san cristobal
# Processing Record 23 of Set 2 | kharan
# Processing Record 24 of Set 2 | yining
# Processing Record 25 of Set 2 | bumba
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | vestmannaeyjar
# Processing Record 28 of Set 2 | goya
# Processing Record 29 of Set 2 | mold
# Processing Record 30 of Set 2 | panguipulli
# Processing Record 31 of Set 2 | maragogi
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | qasigiannguit
# Processing Record 34 of Set 2 | santa barbara
# Processing Record 35 of Set 2 | ambilobe
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | campos novos
# Processing Record 38 of Set 2 | gornopravdinsk
# Processing Record 39 of Set 2 | pedernales
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | mutare
# Processing Record 42 of Set 2 | methoni
# Processing Record 43 of Set 2 | huite
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | lovrenc na pohorju
# Processing Record 46 of Set 2 | cayenne
# Processing Record 47 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | azrow
# City not found. Skipping...
# Processing Record 2 of Set 3 | yurino
# Processing Record 3 of Set 3 | isparta
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | adrar
# Processing Record 6 of Set 3 | faranah
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | de aar
# Processing Record 9 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 3 | erba
# Processing Record 11 of Set 3 | kaabong
# Processing Record 12 of Set 3 | havre-saint-pierre
# Processing Record 13 of Set 3 | grindavik
# Processing Record 14 of Set 3 | kuytun
# Processing Record 15 of Set 3 | eenhana
# Processing Record 16 of Set 3 | taklisah
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | klaebu
# Processing Record 19 of Set 3 | ribeira grande
# Processing Record 20 of Set 3 | melo
# Processing Record 21 of Set 3 | taltal
# Processing Record 22 of Set 3 | joao pinheiro
# Processing Record 23 of Set 3 | augusto correa
# Processing Record 24 of Set 3 | pereira barreto
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | varberg
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | oktyabrskoye
# Processing Record 29 of Set 3 | manaquiri
# Processing Record 30 of Set 3 | manta
# Processing Record 31 of Set 3 | sinazongwe
# Processing Record 32 of Set 3 | noyabrsk
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | comodoro rivadavia
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | bud
# Processing Record 37 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 3 | hit
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 3 | saint-leu
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | quatre cocos
# Processing Record 44 of Set 3 | sakakah
# Processing Record 45 of Set 3 | porbandar
# Processing Record 46 of Set 3 | muros
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | amparafaravola
# Processing Record 49 of Set 3 | bubaque
# Processing Record 50 of Set 3 | rocha
# Processing Record 1 of Set 4 | morondava
# Processing Record 2 of Set 4 | sinnamary
# Processing Record 3 of Set 4 | sao joao da barra
# Processing Record 4 of Set 4 | oktyabrskiy
# Processing Record 5 of Set 4 | bartica
# Processing Record 6 of Set 4 | troitskoye
# Processing Record 7 of Set 4 | mao
# Processing Record 8 of Set 4 | raudeberg
# Processing Record 9 of Set 4 | sidrolandia
# Processing Record 10 of Set 4 | mormugao
# Processing Record 11 of Set 4 | oxelosund
# Processing Record 12 of Set 4 | yarada
# Processing Record 13 of Set 4 | bambous virieux
# Processing Record 14 of Set 4 | shelburne
# Processing Record 15 of Set 4 | varna
# Processing Record 16 of Set 4 | selma
# Processing Record 17 of Set 4 | rio grande
# Processing Record 18 of Set 4 | port hawkesbury
# Processing Record 19 of Set 4 | hammerfest
# Processing Record 20 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 21 of Set 4 | maniitsoq
# Processing Record 22 of Set 4 | verkhnyaya inta
# Processing Record 23 of Set 4 | kudahuvadhoo
# Processing Record 24 of Set 4 | esperanza
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | makat
# Processing Record 27 of Set 4 | paracuru
# Processing Record 28 of Set 4 | peniche
# Processing Record 29 of Set 4 | male
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | cabedelo
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | wronki
# Processing Record 34 of Set 4 | salinopolis
# Processing Record 35 of Set 4 | plattsburgh
# Processing Record 36 of Set 4 | skjervoy
# Processing Record 37 of Set 4 | safranbolu
# Processing Record 38 of Set 4 | korla
# Processing Record 39 of Set 4 | hearst
# Processing Record 40 of Set 4 | navlya
# Processing Record 41 of Set 4 | ndele
# Processing Record 42 of Set 4 | alfreton
# Processing Record 43 of Set 4 | thinadhoo
# Processing Record 44 of Set 4 | lidkoping
# Processing Record 45 of Set 4 | kamenka
# Processing Record 46 of Set 4 | hofn
# Processing Record 47 of Set 4 | isla mujeres
# Processing Record 48 of Set 4 | azare
# Processing Record 49 of Set 4 | zdvinsk
# Processing Record 50 of Set 4 | leh
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | liwale
# Processing Record 3 of Set 5 | kalabo
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | gat
# Processing Record 6 of Set 5 | rio cuarto
# Processing Record 7 of Set 5 | castro
# Processing Record 8 of Set 5 | kalmunai
# Processing Record 9 of Set 5 | mizan teferi
# Processing Record 10 of Set 5 | synya
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | gamba
# Processing Record 15 of Set 5 | ginir
# Processing Record 16 of Set 5 | dwarka
# Processing Record 17 of Set 5 | masvingo
# Processing Record 18 of Set 5 | vallenar
# Processing Record 19 of Set 5 | murgab
# Processing Record 20 of Set 5 | manama
# Processing Record 21 of Set 5 | kasongo-lunda
# Processing Record 22 of Set 5 | coquimbo
# Processing Record 23 of Set 5 | virginia beach
# Processing Record 24 of Set 5 | boa vista
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | rabo de peixe
# Processing Record 27 of Set 5 | chatakonda
# Processing Record 28 of Set 5 | kendrapara
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | laguna
# Processing Record 31 of Set 5 | jibuti
# Processing Record 32 of Set 5 | odesskoye
# Processing Record 33 of Set 5 | madinat sittah uktubar
# Processing Record 34 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 5 | yenagoa
# Processing Record 36 of Set 5 | cajamarca
# Processing Record 37 of Set 5 | mecca
# Processing Record 38 of Set 5 | lumeje
# Processing Record 39 of Set 5 | umm kaddadah
# Processing Record 40 of Set 5 | abnub
# Processing Record 41 of Set 5 | porto novo
# Processing Record 42 of Set 5 | itarema
# Processing Record 43 of Set 5 | ghosi
# Processing Record 44 of Set 5 | mana
# Processing Record 45 of Set 5 | jacareacanga
# Processing Record 46 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 47 of Set 5 | khromtau
# Processing Record 48 of Set 5 | ponta delgada
# Processing Record 49 of Set 5 | inhambane
# Processing Record 50 of Set 5 | jutai
# Processing Record 1 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 6 | bayaguana
# Processing Record 3 of Set 6 | naraina
# Processing Record 4 of Set 6 | bondo
# Processing Record 5 of Set 6 | svetlyy
# Processing Record 6 of Set 6 | mount pleasant
# Processing Record 7 of Set 6 | alakurtti
# Processing Record 8 of Set 6 | aksarka
# Processing Record 9 of Set 6 | paoua
# Processing Record 10 of Set 6 | hun
# Processing Record 11 of Set 6 | amboasary
# Processing Record 12 of Set 6 | iralaya
# Processing Record 13 of Set 6 | isakly
# Processing Record 14 of Set 6 | muana
# Processing Record 15 of Set 6 | cockburn town
# Processing Record 16 of Set 6 | palmas de monte alto
# Processing Record 17 of Set 6 | corum
# Processing Record 18 of Set 6 | daneti
# Processing Record 19 of Set 6 | artigas
# Processing Record 20 of Set 6 | priyutnoye
# Processing Record 21 of Set 6 | sechura
# Processing Record 22 of Set 6 | porto walter
# Processing Record 23 of Set 6 | diffa
# Processing Record 24 of Set 6 | qaqortoq
# Processing Record 25 of Set 6 | nekhayevskiy
# Processing Record 26 of Set 6 | kant
# Processing Record 27 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 6 | ayagoz
# Processing Record 29 of Set 6 | lagos
# Processing Record 30 of Set 6 | tazovskiy
# Processing Record 31 of Set 6 | santa comba
# Processing Record 32 of Set 6 | camana
# Processing Record 33 of Set 6 | den helder
# Processing Record 34 of Set 6 | krasnoselkup
# Processing Record 35 of Set 6 | sovetskiy
# Processing Record 36 of Set 6 | maldonado
# Processing Record 37 of Set 6 | tostamaa
# City not found. Skipping...
# Processing Record 38 of Set 6 | bandarbeyla
# Processing Record 39 of Set 6 | buta
# Processing Record 40 of Set 6 | pitimbu
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | trinidad
# Processing Record 43 of Set 6 | binga
# Processing Record 44 of Set 6 | lubao
# Processing Record 45 of Set 6 | goderich
# Processing Record 46 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 47 of Set 6 | skala fourkas
# Processing Record 48 of Set 6 | atar
# Processing Record 49 of Set 6 | magaria
# Processing Record 50 of Set 6 | iquique
# Processing Record 1 of Set 7 | sao felix do xingu
# Processing Record 2 of Set 7 | vawkavysk
# Processing Record 3 of Set 7 | awbari
# Processing Record 4 of Set 7 | nisia floresta
# Processing Record 5 of Set 7 | mayumba
# Processing Record 6 of Set 7 | chiredzi
# Processing Record 7 of Set 7 | havoysund
# Processing Record 8 of Set 7 | los llanos de aridane
# Processing Record 9 of Set 7 | sao geraldo do araguaia
# Processing Record 10 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 7 | qorveh
# Processing Record 12 of Set 7 | zastron
# Processing Record 13 of Set 7 | artyshta
# Processing Record 14 of Set 7 | paamiut
# Processing Record 15 of Set 7 | sturgeon falls
# Processing Record 16 of Set 7 | tocopilla
# Processing Record 17 of Set 7 | somerset east
# Processing Record 18 of Set 7 | terrak
# Processing Record 19 of Set 7 | brae
# Processing Record 20 of Set 7 | srivardhan
# Processing Record 21 of Set 7 | alibag
# Processing Record 22 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 7 | sabha
# Processing Record 24 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 7 | vila franca do campo
# Processing Record 26 of Set 7 | amalfi
# Processing Record 27 of Set 7 | caraballeda
# Processing Record 28 of Set 7 | willowmore
# Processing Record 29 of Set 7 | melbu
# Processing Record 30 of Set 7 | urucara
# Processing Record 31 of Set 7 | beira
# Processing Record 32 of Set 7 | malpe
# Processing Record 33 of Set 7 | grand gaube
# Processing Record 34 of Set 7 | anloga
# Processing Record 35 of Set 7 | ekibastuz
# Processing Record 36 of Set 7 | pizarro
# Processing Record 37 of Set 7 | marzuq
# Processing Record 38 of Set 7 | isoka
# Processing Record 39 of Set 7 | sept-iles
# Processing Record 40 of Set 7 | cartagena del chaira
# Processing Record 41 of Set 7 | bucak
# Processing Record 42 of Set 7 | mezhdurechenskiy
# Processing Record 43 of Set 7 | general pico
# Processing Record 44 of Set 7 | kiruna
# Processing Record 45 of Set 7 | monrovia
# Processing Record 46 of Set 7 | bom jesus
# Processing Record 47 of Set 7 | mugumu
# Processing Record 48 of Set 7 | saint-georges
# Processing Record 49 of Set 7 | ilinogorsk
# City not found. Skipping...
# Processing Record 50 of Set 7 | san carlos de bariloche
# Processing Record 1 of Set 8 | araouane
# Processing Record 2 of Set 8 | kapoeta
# Processing Record 3 of Set 8 | burica
# City not found. Skipping...
# Processing Record 4 of Set 8 | saint-pierre
# Processing Record 5 of Set 8 | nicoya
# Processing Record 6 of Set 8 | dhidhdhoo
# Processing Record 7 of Set 8 | winneba
# Processing Record 8 of Set 8 | batticaloa
# Processing Record 9 of Set 8 | jalu
# Processing Record 10 of Set 8 | sao filipe
# Processing Record 11 of Set 8 | bell ville
# Processing Record 12 of Set 8 | benghazi
# Processing Record 13 of Set 8 | chapais
# Processing Record 14 of Set 8 | nuuk
# Processing Record 15 of Set 8 | moyobamba
# Processing Record 16 of Set 8 | dothan
# Processing Record 17 of Set 8 | dharchula
# Processing Record 18 of Set 8 | taoudenni
# Processing Record 19 of Set 8 | bristol
# Processing Record 20 of Set 8 | marawi
# Processing Record 21 of Set 8 | kathmandu
# Processing Record 22 of Set 8 | jaque
# Processing Record 23 of Set 8 | edd
# Processing Record 24 of Set 8 | garissa
# Processing Record 25 of Set 8 | dourados
# Processing Record 26 of Set 8 | arona
# Processing Record 27 of Set 8 | jaisalmer
# Processing Record 28 of Set 8 | saint-paul
# Processing Record 29 of Set 8 | zaysan
# Processing Record 30 of Set 8 | mvuma
# Processing Record 31 of Set 8 | abha
# Processing Record 32 of Set 8 | pietarsaari
# Processing Record 33 of Set 8 | marsabit
# Processing Record 34 of Set 8 | visnes
# Processing Record 35 of Set 8 | dingle
# Processing Record 36 of Set 8 | carnarvon
# Processing Record 37 of Set 8 | bonfim
# Processing Record 38 of Set 8 | nouakchott
# Processing Record 39 of Set 8 | riyadh
# Processing Record 40 of Set 8 | narayangarh
# Processing Record 41 of Set 8 | zhanaozen
# Processing Record 42 of Set 8 | hamilton
# Processing Record 43 of Set 8 | monroe
# Processing Record 44 of Set 8 | yei
# Processing Record 45 of Set 8 | paita
# Processing Record 46 of Set 8 | khudumelapye
# Processing Record 47 of Set 8 | biala podlaska
# Processing Record 48 of Set 8 | liverpool
# Processing Record 49 of Set 8 | montepuez
# Processing Record 50 of Set 8 | undory
# Processing Record 1 of Set 9 | richards bay
# Processing Record 2 of Set 9 | marfino
# Processing Record 3 of Set 9 | igarka
# Processing Record 4 of Set 9 | channel-port aux basques
# Processing Record 5 of Set 9 | diego de almagro
# Processing Record 6 of Set 9 | husavik
# Processing Record 7 of Set 9 | villazon
# Processing Record 8 of Set 9 | saint-joseph
# Processing Record 9 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 10 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | cozumel
# Processing Record 12 of Set 9 | inirida
# Processing Record 13 of Set 9 | las palmas
# Processing Record 14 of Set 9 | bouca
# Processing Record 15 of Set 9 | abu kamal
# Processing Record 16 of Set 9 | balkhash
# Processing Record 17 of Set 9 | kabelvag
# Processing Record 18 of Set 9 | binghamton
# Processing Record 19 of Set 9 | french harbor
# Processing Record 20 of Set 9 | ilebo
# Processing Record 21 of Set 9 | buraydah
# Processing Record 22 of Set 9 | touros
# Processing Record 23 of Set 9 | vuktyl
# Processing Record 24 of Set 9 | yegorlykskaya
# Processing Record 25 of Set 9 | brockville
# Processing Record 26 of Set 9 | progreso
# Processing Record 27 of Set 9 | pavilosta
# Processing Record 28 of Set 9 | burgos
# Processing Record 29 of Set 9 | mercedes
# Processing Record 30 of Set 9 | mjolby
# Processing Record 31 of Set 9 | samsun
# Processing Record 32 of Set 9 | mamallapuram
# Processing Record 33 of Set 9 | ipixuna
# Processing Record 34 of Set 9 | omboue
# Processing Record 35 of Set 9 | balkanabat
# Processing Record 36 of Set 9 | valdivia
# Processing Record 37 of Set 9 | ormara
# Processing Record 38 of Set 9 | viransehir
# Processing Record 39 of Set 9 | kaliganj
# Processing Record 40 of Set 9 | moose factory
# Processing Record 41 of Set 9 | camden
# Processing Record 42 of Set 9 | troyes
# Processing Record 43 of Set 9 | blacksburg
# Processing Record 44 of Set 9 | kazerun
# Processing Record 45 of Set 9 | hualmay
# Processing Record 46 of Set 9 | luanda
# Processing Record 47 of Set 9 | pidhorodne
# Processing Record 48 of Set 9 | mugla
# Processing Record 49 of Set 9 | goryachegorsk
# Processing Record 50 of Set 9 | parana
# Processing Record 1 of Set 10 | koulikoro
# Processing Record 2 of Set 10 | port-gentil
# Processing Record 3 of Set 10 | amapa
# Processing Record 4 of Set 10 | berlevag
# Processing Record 5 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 6 of Set 10 | cataguases
# Processing Record 7 of Set 10 | massaguet
# Processing Record 8 of Set 10 | beyneu
# Processing Record 9 of Set 10 | miguelopolis
# Processing Record 10 of Set 10 | maracas
# Processing Record 11 of Set 10 | pervomayskoye
# Processing Record 12 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 13 of Set 10 | shache
# Processing Record 14 of Set 10 | zverinogolovskoye
# Processing Record 15 of Set 10 | nokaneng
# Processing Record 16 of Set 10 | awjilah
# Processing Record 17 of Set 10 | of
# City not found. Skipping...
# Processing Record 18 of Set 10 | lusaka
# Processing Record 19 of Set 10 | tres arroyos
# Processing Record 20 of Set 10 | takoradi
# Processing Record 21 of Set 10 | porto murtinho
# Processing Record 22 of Set 10 | estrela
# Processing Record 23 of Set 10 | clyde river
# Processing Record 24 of Set 10 | wattegama
# Processing Record 25 of Set 10 | sur
# Processing Record 26 of Set 10 | chukhloma
# Processing Record 27 of Set 10 | sinjar
# Processing Record 28 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 10 | oussouye
# Processing Record 30 of Set 10 | jorpeland
# Processing Record 31 of Set 10 | merrill
# Processing Record 32 of Set 10 | turbat
# Processing Record 33 of Set 10 | worthing
# Processing Record 34 of Set 10 | berbera
# Processing Record 35 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 10 | bom jesus da lapa
# Processing Record 37 of Set 10 | adre
# Processing Record 38 of Set 10 | kotri
# Processing Record 39 of Set 10 | kaoma
# Processing Record 40 of Set 10 | arica
# Processing Record 41 of Set 10 | malartic
# Processing Record 42 of Set 10 | gamboula
# Processing Record 43 of Set 10 | bull savanna
# Processing Record 44 of Set 10 | kruisfontein
# Processing Record 45 of Set 10 | lyngseidet
# Processing Record 46 of Set 10 | jacqueville
# Processing Record 47 of Set 10 | san pedro
# Processing Record 48 of Set 10 | kassala
# Processing Record 49 of Set 10 | mehrabpur
# Processing Record 50 of Set 10 | nizwa
# Processing Record 1 of Set 11 | paveh
# Processing Record 2 of Set 11 | cap malheureux
# Processing Record 3 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 4 of Set 11 | zvishavane
# Processing Record 5 of Set 11 | gayeri
# Processing Record 6 of Set 11 | barmer
# Processing Record 7 of Set 11 | bodden town
# Processing Record 8 of Set 11 | kavaratti
# Processing Record 9 of Set 11 | noicattaro
# Processing Record 10 of Set 11 | kulhudhuffushi
# Processing Record 11 of Set 11 | puri
# Processing Record 12 of Set 11 | raga
# Processing Record 13 of Set 11 | kamyshlov
# Processing Record 14 of Set 11 | loiza
# Processing Record 15 of Set 11 | svetlogorsk
# Processing Record 16 of Set 11 | west bay
# Processing Record 17 of Set 11 | bojnurd
# Processing Record 18 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 19 of Set 11 | george town
# Processing Record 20 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 21 of Set 11 | coihaique
# Processing Record 22 of Set 11 | wilmington
# Processing Record 23 of Set 11 | turtas
# Processing Record 24 of Set 11 | neuquen
# Processing Record 25 of Set 11 | mahenge
# Processing Record 26 of Set 11 | rio gallegos
# Processing Record 27 of Set 11 | wajir
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | bushehr
# Processing Record 30 of Set 11 | bonavista
# Processing Record 31 of Set 11 | gacko
# Processing Record 32 of Set 11 | tall kayf
# Processing Record 33 of Set 11 | arlit
# Processing Record 34 of Set 11 | rawson
# Processing Record 35 of Set 11 | jalingo
# Processing Record 36 of Set 11 | sao jose da coroa grande
# Processing Record 37 of Set 11 | dudinka
# Processing Record 38 of Set 11 | road town
# Processing Record 39 of Set 11 | sorland
# Processing Record 40 of Set 11 | sistranda
# Processing Record 41 of Set 11 | ilhabela
# Processing Record 42 of Set 11 | johi
# Processing Record 43 of Set 11 | port-cartier
# Processing Record 44 of Set 11 | mehamn
# Processing Record 45 of Set 11 | careiro da varzea
# Processing Record 46 of Set 11 | presidencia roque saenz pena
# Processing Record 47 of Set 11 | tucuma
# Processing Record 48 of Set 11 | alta floresta
# Processing Record 49 of Set 11 | emba
# Processing Record 50 of Set 11 | havelock
# Processing Record 1 of Set 12 | rosa zarate
# Processing Record 2 of Set 12 | opuwo
# Processing Record 3 of Set 12 | barabinsk
# Processing Record 4 of Set 12 | iquitos
# Processing Record 5 of Set 12 | qurayyat
# Processing Record 6 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 12 | fabriano
# Processing Record 8 of Set 12 | bilma
# Processing Record 9 of Set 12 | bethalto
# Processing Record 10 of Set 12 | aripuana
# Processing Record 11 of Set 12 | kalmar
# Processing Record 12 of Set 12 | san nicolas
# Processing Record 13 of Set 12 | ciudad bolivar
# Processing Record 14 of Set 12 | koster
# Processing Record 15 of Set 12 | xuddur
# Processing Record 16 of Set 12 | lakki marwat
# Processing Record 17 of Set 12 | sumbawanga
# Processing Record 18 of Set 12 | dombarovskiy
# Processing Record 19 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 20 of Set 12 | stornoway
# Processing Record 21 of Set 12 | bad goisern
# Processing Record 22 of Set 12 | rockingham
# Processing Record 23 of Set 12 | gao
# Processing Record 24 of Set 12 | san matias
# Processing Record 25 of Set 12 | villa rica
# Processing Record 26 of Set 12 | novocheremshansk
# Processing Record 27 of Set 12 | bonthe
# Processing Record 28 of Set 12 | novoselytsya
# Processing Record 29 of Set 12 | santa lucia
# Processing Record 30 of Set 12 | doha
# Processing Record 31 of Set 12 | galbshtadt
# Processing Record 32 of Set 12 | odoyev
# Processing Record 33 of Set 12 | oranjemund
# Processing Record 34 of Set 12 | ourossogui
# Processing Record 35 of Set 12 | rio tinto
# Processing Record 36 of Set 12 | pozo colorado
# Processing Record 37 of Set 12 | imbituba
# Processing Record 38 of Set 12 | ureki
# Processing Record 39 of Set 12 | santa fe
# Processing Record 40 of Set 12 | plouzane
# Processing Record 41 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 42 of Set 12 | kozhevnikovo
# Processing Record 43 of Set 12 | borgarnes
# Processing Record 44 of Set 12 | felipe carrillo puerto
# Processing Record 45 of Set 12 | kaimur
# City not found. Skipping...
# Processing Record 46 of Set 12 | brigantine
# Processing Record 47 of Set 12 | bouna
# Processing Record 48 of Set 12 | palencia
# Processing Record 49 of Set 12 | vary
# Processing Record 50 of Set 12 | sambava
# Processing Record 1 of Set 13 | douglas
# Processing Record 2 of Set 13 | dolores
# Processing Record 3 of Set 13 | uusikaupunki
# Processing Record 4 of Set 13 | borba
# Processing Record 5 of Set 13 | quchan
# Processing Record 6 of Set 13 | purranque
# Processing Record 7 of Set 13 | sao raimundo nonato
# Processing Record 8 of Set 13 | bhuban
# Processing Record 9 of Set 13 | areosa
# Processing Record 10 of Set 13 | hambantota
# Processing Record 11 of Set 13 | bougouni
# Processing Record 12 of Set 13 | chimbote
# Processing Record 13 of Set 13 | bayburt
# Processing Record 14 of Set 13 | banyo
# Processing Record 15 of Set 13 | derzhavinsk
# Processing Record 16 of Set 13 | dabeiba
# Processing Record 17 of Set 13 | cochrane
# Processing Record 18 of Set 13 | tshikapa
# Processing Record 19 of Set 13 | sarh
# Processing Record 20 of Set 13 | bakel
# Processing Record 21 of Set 13 | jabinyanah
# Processing Record 22 of Set 13 | nioro
# Processing Record 23 of Set 13 | kharp
# Processing Record 24 of Set 13 | campo formoso
# Processing Record 25 of Set 13 | baneh
# Processing Record 26 of Set 13 | turinskaya sloboda
# Processing Record 27 of Set 13 | graaff-reinet
# Processing Record 28 of Set 13 | conakry
# Processing Record 29 of Set 13 | gravdal
# Processing Record 30 of Set 13 | plettenberg bay
# Processing Record 31 of Set 13 | lamu
# Processing Record 32 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 13 | zharkent
# Processing Record 34 of Set 13 | cascais
# Processing Record 35 of Set 13 | bolshoye polpino
# City not found. Skipping...
# Processing Record 36 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 13 | jenbach
# Processing Record 38 of Set 13 | oranjestad
# Processing Record 39 of Set 13 | hurghada
# Processing Record 40 of Set 13 | lerwick
# Processing Record 41 of Set 13 | bana
# Processing Record 42 of Set 13 | wadi maliz
# Processing Record 43 of Set 13 | kargasok
# Processing Record 44 of Set 13 | mapiripan
# Processing Record 45 of Set 13 | bani
# Processing Record 46 of Set 13 | hjelset
# Processing Record 47 of Set 13 | macapa
# Processing Record 48 of Set 13 | loandjili
# Processing Record 49 of Set 13 | upata
# Processing Record 50 of Set 13 | vestmanna
# Processing Record 1 of Set 14 | canandaigua
# Processing Record 2 of Set 14 | bindura
# Processing Record 3 of Set 14 | gerash
# Processing Record 4 of Set 14 | the valley
# Processing Record 5 of Set 14 | sakaraha
# Processing Record 6 of Set 14 | baherden
# Processing Record 7 of Set 14 | winthrop
# Processing Record 8 of Set 14 | grand-lahou
# Processing Record 9 of Set 14 | komsomolets
# Processing Record 10 of Set 14 | tsumeb
# Processing Record 11 of Set 14 | itaituba
# Processing Record 12 of Set 14 | pimentel
# Processing Record 13 of Set 14 | kibaya
# Processing Record 14 of Set 14 | vilhena
# Processing Record 15 of Set 14 | ritchie
# Processing Record 16 of Set 14 | aquidaba
# Processing Record 17 of Set 14 | mahajanga
# Processing Record 18 of Set 14 | banamba
# Processing Record 19 of Set 14 | pauini
# Processing Record 20 of Set 14 | yangambi
# Processing Record 21 of Set 14 | luena
# Processing Record 22 of Set 14 | kharitonovo
# Processing Record 23 of Set 14 | ust-tsilma
# Processing Record 24 of Set 14 | tacoronte
# Processing Record 25 of Set 14 | beloha
# Processing Record 26 of Set 14 | farafangana
# Processing Record 27 of Set 14 | trincomalee
# Processing Record 28 of Set 14 | nainpur
# Processing Record 29 of Set 14 | kargil
# Processing Record 30 of Set 14 | mazamari
# Processing Record 31 of Set 14 | high rock
# Processing Record 32 of Set 14 | kuito
# Processing Record 33 of Set 14 | orichi
# Processing Record 34 of Set 14 | bandundu
# Processing Record 35 of Set 14 | faya
# Processing Record 36 of Set 14 | sabzevar
# Processing Record 37 of Set 14 | lucknow
# Processing Record 38 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 39 of Set 14 | prieska
# Processing Record 40 of Set 14 | tamandare
# Processing Record 41 of Set 14 | marsh harbour
# Processing Record 42 of Set 14 | maamba
# Processing Record 43 of Set 14 | suleja
# Processing Record 44 of Set 14 | lodja
# Processing Record 45 of Set 14 | divnoye
# Processing Record 46 of Set 14 | santa cruz
# Processing Record 47 of Set 14 | nadym
# Processing Record 48 of Set 14 | dalsingh sarai
# Processing Record 49 of Set 14 | tarnogskiy gorodok
# Processing Record 50 of Set 14 | osorno
# Processing Record 1 of Set 15 | olean
# Processing Record 2 of Set 15 | lerik
# Processing Record 3 of Set 15 | rundu
# Processing Record 4 of Set 15 | imeni tsyurupy
# Processing Record 5 of Set 15 | tyup
# Processing Record 6 of Set 15 | kosonsoy
# Processing Record 7 of Set 15 | kjollefjord
# Processing Record 8 of Set 15 | damietta
# Processing Record 9 of Set 15 | indapur
# Processing Record 10 of Set 15 | ostend
# Processing Record 11 of Set 15 | thiruvananthapuram
# Processing Record 12 of Set 15 | nioki
# Processing Record 13 of Set 15 | atasu
# Processing Record 14 of Set 15 | kangaatsiaq
# Processing Record 15 of Set 15 | kez
# Processing Record 16 of Set 15 | lasa
# Processing Record 17 of Set 15 | canto do buriti
# Processing Record 18 of Set 15 | peebles
# Processing Record 19 of Set 15 | matay
# Processing Record 20 of Set 15 | cerrito
# Processing Record 21 of Set 15 | jagatsinghapur
# Processing Record 22 of Set 15 | lodeynoye pole
# Processing Record 23 of Set 15 | matadi
# Processing Record 24 of Set 15 | chicama
# Processing Record 25 of Set 15 | fuerte olimpo
# Processing Record 26 of Set 15 | mandi
# Processing Record 27 of Set 15 | minab
# Processing Record 28 of Set 15 | qandala
# Processing Record 29 of Set 15 | buguruslan
# Processing Record 30 of Set 15 | aksay
# Processing Record 31 of Set 15 | puerto baquerizo moreno
# Processing Record 32 of Set 15 | sioux lookout
# Processing Record 33 of Set 15 | nadvoitsy
# Processing Record 34 of Set 15 | aracruz
# Processing Record 35 of Set 15 | kostomuksha
# Processing Record 36 of Set 15 | chake chake
# Processing Record 37 of Set 15 | gilgit
# Processing Record 38 of Set 15 | gazli
# Processing Record 39 of Set 15 | bela
# Processing Record 40 of Set 15 | olinda
# Processing Record 41 of Set 15 | planaltina
# Processing Record 42 of Set 15 | amalapuram
# Processing Record 43 of Set 15 | bosaso
# Processing Record 44 of Set 15 | khorramabad
# Processing Record 45 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 15 | virarajendrapet
# Processing Record 47 of Set 15 | guayaramerin
# Processing Record 48 of Set 15 | takaungu
# Processing Record 49 of Set 15 | gidam
# Processing Record 50 of Set 15 | marechal candido rondon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia -54.8000 -68.3000     44.26        65          75
# 1         Harper   4.3750  -7.7169     78.44        85         100
# 2  Saint Anthony  45.0205 -93.2180     58.24        76         100
# 3    Port Alfred -33.5906  26.8910     61.25        81          99
# 4        Pastavy  55.1168  26.8326     34.52        64           3
# 5        Talnakh  69.4865  88.3972     18.21        94          90
# 6       Hermanus -34.4187  19.2345     58.06        76          98
# 7      Cape Town -33.9258  18.4232     56.12        90         100
# 8        Margate  51.3813   1.3862     48.31        86           5
# 9          Muzhi  65.3667  64.6667     37.27        91          69
#
#    Wind Speed Country Current Description
# 0        4.61      AR       broken clouds
# 1        1.28      LR          light rain
# 2       14.97      US     overcast clouds
# 3        9.24      ZA     overcast clouds
# 4        9.26      BY           clear sky
# 5       10.65      RU     overcast clouds
# 6        3.33      ZA     overcast clouds
# 7        2.30      ZA                mist
# 8        1.99      GB           clear sky
# 9        7.43      RU       broken clouds

# %%
# Reorder columns in city_data_df DataFrame.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000 -68.3000     44.26        65          75
# 1         Harper      LR   4.3750  -7.7169     78.44        85         100
# 2  Saint Anthony      US  45.0205 -93.2180     58.24        76         100
# 3    Port Alfred      ZA -33.5906  26.8910     61.25        81          99
# 4        Pastavy      BY  55.1168  26.8326     34.52        64           3
# 5        Talnakh      RU  69.4865  88.3972     18.21        94          90
# 6       Hermanus      ZA -34.4187  19.2345     58.06        76          98
# 7      Cape Town      ZA -33.9258  18.4232     56.12        90         100
# 8        Margate      GB  51.3813   1.3862     48.31        86           5
# 9          Muzhi      RU  65.3667  64.6667     37.27        91          69
#
#    Wind Speed Current Description
# 0        4.61       broken clouds
# 1        1.28          light rain
# 2       14.97     overcast clouds
# 3        9.24     overcast clouds
# 4        9.26           clear sky
# 5       10.65     overcast clouds
# 6        3.33     overcast clouds
# 7        2.30                mist
# 8        1.99           clear sky
# 9        7.43       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
